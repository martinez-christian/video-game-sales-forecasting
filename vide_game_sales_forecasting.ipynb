# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Reviewer’s comments – Iteration 3:</b><br>
#   Hello christian!,
#
# I am Alexangel, your reviewer,
#
# Another project successfully completed - well done! 🏆 Your consistent effort and progress are truly commendable.
#
# Our team is here to help you keep pushing forward and honing your skills as you advance through the program.
#
# You can contact me via Tripleten Hub for further feedback. This information is described below.
#
# **What Was Great**:
# - Excellent job on following the structure of the project.
# - You’ve shown strong skills in building the charts in this project.
#
# **Tips for Future Projects**:
# - Consider adding brief comments after the analysis or graph of every dataframe to make your work even more integral.
#
# Congratulations again on your accomplishment! Each project you complete adds to your growing expertise, and it’s exciting to see you make such great strides. Keep up the great work! 🎯
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# ***Name of the reviewer***: Alexangel Bracho
#
# ***Reviewer's Tripleten Hub  link*** : [reviewer's link](https://hub.tripleten.com/u/6b1cbe37)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Reviewer’s comments – Iteration 2:</b><br>
#   Hello christian!,
#
# I am Alexangel, your reviewer,
#
#  First of all, congratulations on re-submitting your project! 🎉
#
#   Taking this step is a big part of your journey into the world of Data, and it’s clear you’re putting in the effort to succeed.
#
#   Our team is here to support your growth, and to help you get the most out of this experience, I’ve returned your project with some suggestions for improvement.
#
# My new comments are marked as `Reviewer's comment 2`. You can contact me via Tripleten Hub for further clarification. This information is described below.
#
#  **What Was Great:**
#  - You’ve done a good job with following the general structure of a project.
#  - Your attempt at building good charts shows promise.
#
#  **Areas to Improve:**
#  - To fully meet the project criteria, you'll need to fix the red comments I left below, I also made some comments and recommendations about how to fix them.
#  - Consider adding brief comments after the analysis of every dataset or chart to make your project even more integral.
#
#  Don’t be discouraged - this is all part of the learning process! Take your time to review the feedback and make the necessary adjustments. Resubmit when you’re ready, and I’m confident you’ll nail it on the next go. Remember, every challenge is an opportunity to grow. You’ve got this! 🏄
#
# -------------------------------------------------------------------------------------------------------------
# Please find my comments below—**I kindly ask that you do not move, modify, or delete them**.
# You can find my comments highlighted in green, yellow, or red boxes like this:
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Success. Everything is done succesfully.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Remarks. Some recommendations.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Needs fixing. The block requires some corrections. Work can't be accepted with the red comments.
# </div>
#
# You can answer me by using this:
# <div class="alert alert-block alert-info">
# <b>Student answer 2</b> <a class="tocSkip"></a>
# </div>
# -------------------------------------------------------------------------------------------------------------
#
# ***Name of the reviewer***: Alexangel Bracho
#
# ***Reviewer’s Tripleten Hub link*** : [reviewer's link](https://hub.tripleten.com/u/6b1cbe37)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Reviewer’s comments – Iteration 1:</b><br>
#   Hello christian!,
#
# I am Alexangel, your current reviewer,
#
#  First of all, congratulations on submitting your project! 🎉
#
#   Taking this step is a big part of your journey into the world of Data, and it’s clear you’re putting in the effort to succeed.
#
#   Our team is here to support your growth, and to help you get the most out of this experience, I’ve returned your project with some suggestions for improvement.
#
# You can contact me via Tripleten Hub for further clarification. This information is described below.
#
#  **What Was Great:**
#  - You’ve done a good job with following the general structure of a project.
#  - Your attempt at building good charts shows promise.
#
#  **Areas to Improve:**
#  - To fully meet the project criteria, you'll need to fix the red comments I left below, I also made some comments and recommendations about how to fix them.
#  - Consider adding brief comments after the analysis of every dataset or chart to make your project even more integral.
#
#  Don’t be discouraged - this is all part of the learning process! Take your time to review the feedback and make the necessary adjustments. Resubmit when you’re ready, and I’m confident you’ll nail it on the next go. Remember, every challenge is an opportunity to grow. You’ve got this! 🏄
#
# -------------------------------------------------------------------------------------------------------------
# Please find my comments below—**I kindly ask that you do not move, modify, or delete them**.
# You can find my comments highlighted in green, yellow, or red boxes like this:
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Success. Everything is done succesfully.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Remarks. Some recommendations.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Needs fixing. The block requires some corrections. Work can't be accepted with the red comments.
# </div>
#
# You can answer me by using this:
# <div class="alert alert-block alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
# </div>
# -------------------------------------------------------------------------------------------------------------
#
# ***Name of the reviewer***: Alexangel Bracho
#
# ***Reviewer’s Tripleten Hub link*** : [reviewer's link](https://hub.tripleten.com/u/6b1cbe37)

# %% [markdown]
# # Video Game Sales Analysis Project
#
# ### PROJECT INTRODUCTION
#
# The video game project is an analytical study of global video game sales, aiming to understand **market performance, regional differences, and consumer preferences**. Using a dataset that includes information on platforms, genres, release years, sales by region, and review scores, the project explores how different factors shape the success of video games.
#
# ## Key Areas of Focus
# - **Sales Trends:** Tracking how the industry has grown and shifted over time, including peaks in console generations and the transition toward digital distribution.
# - **Platform Analysis:** Comparing the performance of consoles and handhelds across North America, Europe, and Japan.
# - **Genre Popularity:** Identifying which types of games perform best globally and regionally, and how these preferences differ between markets.
# - **ESRB Rating Impact:** Studying how age ratings influence sales outcomes in different regions.
# - **Review Scores:** Evaluating the correlation between critic/user reviews and commercial success.
# - **Cross-Platform Performance:** Understanding how games released on multiple systems fare compared to platform exclusives.
#
# ## Goal
# The overall goal is to produce **insights about consumer behavior, regional gaming culture, and market dynamics**, while practicing data cleaning, visualization, and statistical analysis skills in Python. This project provides both **technical experience with data science tools** and **practical knowledge of the video game industry**.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# You should add an introduction about what the project will be about, its objectives and within others.
#
# </div>

# %%
# Import all required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ## Step 1: Loading and Initial Data Exploration
#
# First, let's load our dataset and examine its basic properties:

# %%
# Load the dataset
df = pd.read_csv('/datasets/games.csv')

# %%
# Display basic information about the dataset
print(df.shape)
print(df.head())
print(df.tail())
print(df.columns.tolist())
print(df.info())
print(df.describe())
# Out:
# (16715, 11)
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN
#                                 Name Platform  Year_of_Release       Genre  \
# ...

# %%
# 🔹 1. Exact duplicate rows (all columns identical)
exact_dupes = df.duplicated().sum()
print("Total exact duplicate rows:", exact_dupes)

# 🔹 2. Rows with duplicate game names (not necessarily exact row duplicates)
dupe_name_rows = df[df.duplicated(subset=["Name"], keep=False)]
print("Total rows with duplicate names:", len(dupe_name_rows))

# 🔹 3. Unique game titles that are duplicated
dupe_name_count = df["Name"].value_counts().gt(1).sum()
print("Unique game names with duplicates:", dupe_name_count)

# 🔹 4. Preview a few duplicated titles
print("\nExamples of duplicated game titles:")
print(df["Name"].value_counts()[df["Name"].value_counts() > 1].head(10))
# Out:
# Total exact duplicate rows: 0
# Total rows with duplicate names: 7961
# Unique game names with duplicates: 2805
#
# Examples of duplicated game titles:
# Need for Speed: Most Wanted                12
# Ratatouille                                 9
# LEGO Marvel Super Heroes                    9
# Madden NFL 07                               9
# FIFA 14                                     9
# Monopoly                                    8
# Terraria                                    8
# Madden NFL 08                               8
# LEGO Star Wars II: The Original Trilogy     8
# LEGO Harry Potter: Years 5-7                8
# Name: Name, dtype: int64

# %% [markdown]
# ### Key Questions to Answer:
# - What's the total number of records in our dataset?
# - What data types are present in each column?
# - Are there any obvious issues with the data?
# - Do we see any immediate patterns or anomalies?

# %% [markdown]
# ## Exploratory Data Check
#
# ### 1. What's the total number of records in our dataset?
# - **16,715 records** (rows) across 9 columns.
#
# ---
#
# ### 2. What data types are present in each column?
# - `Name` → object (string)
# - `Platform` → object (string)
# - `Year_of_Release` → float64 (numeric, but should be integer)
# - `Genre` → object (string)
# - `NA_sales`, `EU_sales`, `JP_sales`, `Other_sales` → float64
# - `Critic_Score` → float64
# - `User_Score` → object (stored as string due to values like "tbd")
# - `Rating` → object (string / categorical)
#
# ---
#
# ### 3. Are there any obvious issues with the data?
# - **Duplicates:** 2,805 unique game names duplicated (~48% of dataset).
# - **Cross-platform entries:** Same game listed multiple times for different platforms (e.g., FIFA, Pokémon, LEGO).
# - **Naming inconsistencies:** Variations like *LEGO* vs *Lego*.
# - **Missing values:** `NaN` values in `Name`, `Genre`, `Year_of_Release`, and `User_Score`.
# - **Data type mismatches:** `Year_of_Release` is float instead of int; `User_Score` stored as string.
#
# ---
#
# ### 4. Do we see any immediate patterns or anomalies?
# - **Franchise dominance:** Sports (FIFA, Madden NFL) and movie tie-ins (LEGO, Ratatouille) appear heavily duplicated.
# - **Cross-platform strategy:** Many top titles released across 7–12 platforms, inflating duplicate counts.
# - **Sales fragmentation:** Sales split by platform, which may understate total game popularity.
# - **Anomalous years:** Some games with missing or unusual release years (pre-1980).
# - **High duplication counts:** Titles like *Need for Speed: Most Wanted* appear up to 12 times.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Good work with the preview of the data and also answering the these questions.
#
# </div>

# %% [markdown]
# ## Step 2: Data Preparation
#
# ### 2.1 Standardizing Column Names

# %%
# Convert column names to lowercase
# Make all column names lowercase and replace spaces with underscores
df.columns = (
    df.columns
      .str.strip()            # remove leading/trailing spaces
      .str.lower()            # convert to lowercase
      .str.replace(' ', '_')  # replace spaces with underscores
      .str.replace('-', '_')  # replace hyphens with underscores
)

# %%
# Verify the changes
print("Standardized column names:", df.columns.tolist())
# Out:
# Standardized column names: ['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating']

# %% [markdown]
# ### 2.2 Data Type Conversion

# %%
# Check current data types
print(df.dtypes)
# Out:
# name                object
# platform            object
# year_of_release    float64
# genre               object
# na_sales           float64
# eu_sales           float64
# jp_sales           float64
# other_sales        float64
# critic_score       float64
# user_score          object
# rating              object
# dtype: object

# %%
# Make changes to data types if necessary
# Describe the columns where the data types have been changed and why.

# Convert year_of_release to integer (after dropping/filling NaNs)
df = df.dropna(subset=['year_of_release']).copy()
df['year_of_release'] = df['year_of_release'].astype('int64')

# year of release is currently a float, but should be int.

# Verify
print(df['year_of_release'].dtype)      # -> int64
# Out:
# int64

# %%
# Pay attention to the abbreviation TBD (to be determined). Specify how you intend to handle such case

# Convert user_score to numeric (float)
# The dataset sometimes stores "tbd" (to be determined) in user_score.
# These are not valid numeric ratings, so we will replace them with NaN.
df['user_score'] = pd.to_numeric(df['user_score'], errors='coerce')

# Verify the change
print(df['user_score'].dtype)        # -> float64
print(df['user_score'].isna().sum()) # count NaNs (includes "tbd" + missing values)
# Out:
# float64
# 8983

# %% [markdown]
# ### 2.3 Handling Missing Values

# %%
# Examine missing values
print(df.isna().sum())
# Out:
# name                  2
# platform              0
# year_of_release       0
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8463
# user_score         8983
# rating             6678
# dtype: int64

# %%
# Calculate percentage of missing values
missing_percent = df.isna().mean() * 100
print(missing_percent)
# Out:
# name                0.012161
# platform            0.000000
# year_of_release     0.000000
# genre               0.012161
# na_sales            0.000000
# eu_sales            0.000000
# jp_sales            0.000000
# other_sales         0.000000
# critic_score       51.459321
# user_score         54.621184
# rating             40.605618
# dtype: float64

# %%
# Analyze patterns in missing values
# Do missing user_score and missing critic_score overlap?

df['user_score_missing'] = df['user_score'].isna().astype(int)
print(df.groupby('user_score_missing')['genre'].value_counts(normalize=True))
#This will tell me if a missing score is more common in certain areas
# Out:
# user_score_missing  genre
# 0                   Action          0.240654
#                     Sports          0.144848
#                     Shooter         0.121265
#                     Role-Playing    0.098754
#                     Racing          0.084282
#                     Misc            0.057484
#                     Platform        0.056814
#                     Fighting        0.052928
#                     Simulation      0.045424
#                     Strategy        0.040868
#                     Adventure       0.039930
#                     Puzzle          0.016749
# 1                   Action          0.168244
#                     Misc            0.143859
#                     Sports          0.136399
#                     Adventure       0.110789
#                     Role-Playing    0.082842
#                     Racing          0.066474
#                     Simulation      0.057677
#                     Platform        0.050551
# ...

# %%
# Handle missing values based on analysis

# 1. Year of release
# Still drop missing years (critical for time-based analysis)
df = df.dropna(subset=["year_of_release"])

# 2. User score
# KEEP missing values (NaN = not reviewed yet)
# No imputation to avoid distorting results

# 3. Critic score
# KEEP missing values (NaN = never reviewed)
# No imputation

# 4. Rating
# Fill missing with "Unknown" to avoid dropping many older/international games
df["rating"] = df["rating"].fillna("Unknown")

# Verify
print(df.isna().sum())
# Out:
# name                     2
# platform                 0
# year_of_release          0
# genre                    2
# na_sales                 0
# eu_sales                 0
# jp_sales                 0
# other_sales              0
# critic_score          8463
# user_score            8983
# rating                   0
# user_score_missing       0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good work with the handling of the missing values.
#
# </div>

# %%
# Why do you think the values are missing? Give possible reasons. # Explain why you filled in the missing values as you did or why you decided to leave them blank.

# %% [markdown]
# ## Handling Missing Values
#
# ### `year_of_release`
# - **Reason for missingness:** Some games may not have had an official release year recorded (especially older or poorly documented titles).
# - **Decision:** Dropped these rows, since the release year is essential for analyzing trends over time.
#
# ---
#
# ### `user_score`
# - **Reason for missingness:** Many entries contained `"tbd"` (“to be determined”), meaning the game had not received enough user reviews at the time of data collection.
# - **Decision:** Dropped these rows to avoid misleading analyses, since imputing values would artificially distort user sentiment.
#
# ---
#
# ### `critic_score`
# - **Reason for missingness:** Smaller or niche games were sometimes never reviewed by critics.
# - **Decision:** Dropped these rows, as including them without valid scores would bias the comparison between critic and user ratings.
#
# ---
#
# ### `rating`
# - **Reason for missingness:** ESRB ratings are not always available for games released outside North America, or for older titles released before the ESRB system.
# - **Decision:** Filled missing values with `"Unknown"` to retain these rows while clearly indicating that a rating is unavailable.
#
# ---
#
# **Summary:**
# I dropped rows where missingness made the record unusable (`year_of_release`, `user_score`, `critic_score`). For `rating`, I filled with `"Unknown"` when the absence was due to regional or historical differences, allowing the rest of the record to remain useful.

# %% [markdown]
# ### 2.4 Calculate Total Sales

# %%
# Calculate total sales across all regions and put them in a different column
# Calculate total sales across all regions
df['total_sales'] = (
    df['na_sales'] +
    df['eu_sales'] +
    df['jp_sales'] +
    df['other_sales']
)

# Verify
print(df[['na_sales','eu_sales','jp_sales','other_sales','total_sales']].head())
# Out:
#    na_sales  eu_sales  jp_sales  other_sales  total_sales
# 0     41.36     28.96      3.77         8.45        82.54
# 1     29.08      3.58      6.81         0.77        40.24
# 2     15.68     12.76      3.79         3.29        35.52
# 3     15.61     10.93      3.28         2.95        32.77
# 4     11.27      8.89     10.22         1.00        31.38

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Good work calculating the total sales. In general, good job with the `Step 2: Data Preparation` stage, except for the red comment left above.
#
# </div>

# %% [markdown]
# # Step 3: Analyzing Video Game Sales Data
#
# ## 3.1 Temporal Analysis of Game Releases
# Let's first examine the distribution of game releases across different years to understand our data's coverage and significance:

# %%
# Create a DataFrame with game releases by year

games_per_year = (
    df['year_of_release']
    .value_counts()
    .sort_index()
    .rename_axis('year_of_release')
    .reset_index(name='number_of_games')
)

print(games_per_year.head(15))
# Out:
#     year_of_release  number_of_games
# 0              1980                9
# 1              1981               46
# 2              1982               36
# 3              1983               17
# 4              1984               14
# 5              1985               14
# 6              1986               21
# 7              1987               16
# 8              1988               15
# 9              1989               17
# 10             1990               16
# 11             1991               41
# 12             1992               43
# 13             1993               62
# 14             1994              121

# %%
# Visualize the distribution of games across years
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.bar(games_per_year['year_of_release'],
        games_per_year['number_of_games'],
        color='lightgreen', edgecolor='black')

plt.title('Number of Video Game Releases per Year')
plt.xlabel('Year of Release')
plt.ylabel('Number of Games Released')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# # Display summary statistics for each year

# %% [markdown]
# ## Display Summary Statistics for Each Year
#
# The number of video game releases grew slowly until the mid-1990s.
# Then, releases expanded rapidly through the 2000s, **peaking in 2008–2009**.
#
# This reflects:
# - The growth of the industry during the PlayStation 2, Xbox 360, and Wii era.
# - The increasing global demand for video games.
#
# After 2010, the number of releases declined, likely due to:
# - The transition to **digital distribution**.
# - The industry shift toward **fewer, larger-budget titles**.
#
# ⚠️ Data after 2016 should be interpreted cautiously, as the dataset may not fully capture more recent releases.

# %% [markdown]
# ### Questions to Consider:
# - Which years show significant numbers of game releases?
# - Are there any notable trends or patterns in the number of releases?
# - Is there enough recent data to make predictions for 2017?

# %% [markdown]
# ## Display Summary Statistics for Each Year
#
# - The number of video game releases grew slowly until the **mid-1990s**.
# - Releases expanded rapidly through the **2000s**, peaking in **2008–2009**.
# - This trend reflects:
#   - Growth of the industry during the PlayStation 2, Xbox 360, and Wii era.
#   - Increasing global demand for video games.
# - After **2010**, releases declined due to:
#   - Transition to digital distribution.
#   - Shift toward fewer, larger-budget titles.
# - ⚠️ Data after **2016** should be treated cautiously, as the dataset may not fully capture recent releases.

# %% [markdown]
# ## 3.2 Platform Sales Analysis Over Time
#
# Now let's analyze how sales vary across platforms and years:

# %%
# Calculate total sales by platform and year
sales_by_platform_year = (
    df.groupby(['platform', 'year_of_release'])['total_sales']
    .sum()
    .reset_index()
    .sort_values(['year_of_release', 'platform'])
)

print(sales_by_platform_year.head(15))
# Out:
#    platform  year_of_release  total_sales
# 0      2600             1980        11.38
# 1      2600             1981        35.68
# 2      2600             1982        28.88
# 3      2600             1983         5.84
# 77      NES             1983        10.96
# 4      2600             1984         0.27
# 78      NES             1984        50.08
# 5      2600             1985         0.45
# 25       DS             1985         0.02
# 79      NES             1985        53.44
# 93       PC             1985         0.04
# 6      2600             1986         0.67
# 80      NES             1986        36.41
# 7      2600             1987         1.94
# 81      NES             1987        19.76

# %%
# Create a heatmap of platform sales over time

import seaborn as sns
import matplotlib.pyplot as plt

# Pivot and plot in one go
sales_pivot = df.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum', fill_value=0)

plt.figure(figsize=(14,8))
sns.heatmap(sales_pivot, cmap="YlGnBu")
plt.title("Total Sales by Platform and Year")
plt.show()

# %%
# Identify platforms with declining sales

import seaborn as sns
import matplotlib.pyplot as plt

# Pick top 6 platforms by total sales
top_platforms = sales_by_platform_year.groupby('platform')['total_sales'].sum().nlargest(6).index

# Filter only those platforms
filtered = sales_by_platform_year[sales_by_platform_year['platform'].isin(top_platforms)]

# Plot with seaborn
plt.figure(figsize=(12,6))
sns.lineplot(data=filtered, x='year_of_release', y='total_sales', hue='platform', marker="o")

plt.title("Sales Trends for Top Platforms")
plt.xlabel("Year of Release")
plt.ylabel("Total Sales (millions)")
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ### Questions to Consider:
# - Which platforms show consistent sales over time?
# - Can you identify platforms that have disappeared from the market?
# - What's the typical lifecycle of a gaming platform?

# %% [markdown]
# ### Interpretation of Platform Sales Trends
#
# - **Consistent performers:** Platforms like **PS2, DS, and Wii** dominated during their lifespans, showing strong peaks in the mid-2000s. More recent platforms (e.g., **PS4, XOne**) maintained steadier sales in later years.
# - **Disappeared platforms:** Older systems such as **NES, SNES, N64, Dreamcast, PSP, and Wii** show sharp declines and eventually vanish from the dataset as support ended.
# - **Typical lifecycle:** A gaming platform follows a clear pattern — **launch → rapid growth → peak sales (often 3–5 years in) → gradual decline → obsolescence** as newer generations replace it.

# %% [markdown]
# ## 3.3 Determining Relevant Time Period
#
# Based on your analysis above, determine the appropriate time period for predicting 2017 sales:

# %%
# Your code here to filter the dataset to relevant years
# Example:
# relevant_years = [XXXX, XXXX, XXXX] # Replace with your chosen years
# df_relevant = df[df['year_of_release'].isin(relevant_years)]

# Justify your choice with data
# Your code here to filter the dataset to relevant years

# Choose 2000–2015 as relevant years (strongest data coverage)
relevant_years = list(range(2013, 2017))
df_relevant = df[df['year_of_release'].isin(relevant_years)]

print(df_relevant['year_of_release'].value_counts().sort_index())
# Out:
# 2013    544
# 2014    581
# 2015    606
# 2016    502
# Name: year_of_release, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 3</b> <a class="tocSkip"></a>
#
# Good job updating the range of years.
#
# </div>

# %% [markdown]
# ### Document Your Decision:
# - What years did you select and why?
# - How does this period reflect current market conditions?
# - What factors influenced your decision?

# %% [markdown]
# - **Years Selected:** 2000–2015.
# - **Reasoning:** Data before 2000 includes too few releases to be reliable, while data after 2016 is incomplete due to dataset cutoff. The period 2000–2015 captures the industry’s peak, with the highest volume of game releases and sales across major platforms such as PS2, Wii, Xbox 360, and DS.
# - **Reflection of Market Conditions:** This range reflects the most representative years of the modern video game industry, where both physical and digital markets were strong and console competition was at its peak.
# - **Factors Influencing the Decision:**
#   - Sufficient data density for meaningful analysis.
#   - Avoiding early years with sparse coverage.
#   - Excluding later years where missing data would bias results.
#   - Capturing platform life cycles and sales trends critical for forecasting.

# %% [markdown]
# ## 3.4 Platform Performance Analysis
#
# Using your selected time period, let's analyze platform performance:

# %%
# Analyze platform sales trends
# Group by platform and year to see how sales evolved

# Group by platform and year to see sales trends over time
platform_trends = (
    df_relevant.groupby(['platform', 'year_of_release'])['total_sales']
    .sum()
    .reset_index()
)

# Identify top 6 platforms by total sales
top_platforms = (
    df_relevant.groupby('platform')['total_sales']
    .sum()
    .nlargest(6)
    .index
)

# Filter for only those top platforms
filtered = platform_trends[platform_trends['platform'].isin(top_platforms)]

# Plot sales trends for top platforms
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.lineplot(data=filtered, x='year_of_release', y='total_sales', hue='platform', marker="o")

plt.title("Platform Sales Trends (2000–2015)")
plt.xlabel("Year of Release")
plt.ylabel("Total Sales (millions)")
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
# Sort platforms by total sales

# Sort platforms by total sales in descending order
platform_sales_sorted = (
    df_relevant.groupby('platform')['total_sales']
    .sum()
    .reset_index()
    .sort_values(by='total_sales', ascending=False)
)

print(platform_sales_sorted.head(10))
# Out:
#    platform  total_sales
# 4       PS4       314.14
# 3       PS3       181.43
# 10     XOne       159.32
# 0       3DS       143.25
# 9      X360       136.80
# 8      WiiU        64.63
# 2        PC        39.43
# 6       PSV        32.99
# 7       Wii        13.66
# 5       PSP         3.50

# %%
# Visualize top platforms
# Calculate year-over-year growth for each platform
# Your code here to calculate and visualize platform growth rates

import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.bar(platform_sales_sorted['platform'], platform_sales_sorted['total_sales'], color='skyblue', edgecolor='black')

plt.title("Total Sales by Platform (2000–2015)")
plt.xlabel("Platform")
plt.ylabel("Total Sales (millions)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 3.5 Sales Distribution Analysis
#
# Let's examine the distribution of sales across platforms:

# %%
# Create box plot of sales by platform

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(14,8))
sns.boxplot(data=df_relevant, x='platform', y='total_sales')

plt.title("Distribution of Game Sales by Platform (2000–2015)")
plt.xlabel("Platform")
plt.ylabel("Sales (millions)")
plt.xticks(rotation=45)
plt.ylim(0, 2)  # optional: limit y-axis to reduce effect of outliers
plt.show()

# %%
# Calculate detailed statistics for each platform

# Group by platform and describe sales
platform_stats = df_relevant.groupby('platform')['total_sales'].describe()

print(platform_stats.head(10))
# Out:
#           count      mean       std   min     25%    50%     75%    max
# platform
# 3DS       303.0  0.472772  1.381347  0.01  0.0400  0.090  0.2800  14.60
# DS          8.0  0.192500  0.172026  0.03  0.0675  0.150  0.2525   0.51
# PC        189.0  0.208624  0.352304  0.01  0.0300  0.080  0.2300   3.05
# PS3       345.0  0.525884  1.451939  0.01  0.0400  0.150  0.5100  21.05
# PS4       392.0  0.801378  1.609456  0.01  0.0600  0.200  0.7300  14.63
# PSP        67.0  0.052239  0.059768  0.01  0.0150  0.020  0.0700   0.24
# PSV       358.0  0.092151  0.153816  0.01  0.0200  0.040  0.1100   1.96
# Wii        23.0  0.593913  0.915432  0.01  0.0450  0.180  0.7550   3.58
# WiiU      115.0  0.562000  1.038778  0.01  0.0600  0.200  0.5950   7.09
# X360      186.0  0.735484  1.663275  0.01  0.0800  0.265  0.7950  16.27

# %% [markdown]
# ## 3.6 Review Score Impact Analysis
#
# Select a popular platform and analyze how reviews affect sales:

# %% [markdown]
# # Choose a popular platform based on your previous analysis
#
# - 📊 **High global sales** — PS4 dominated its generation with consistently strong sales worldwide.
# - 🕹 **Large game library** — plenty of titles with both critic and user reviews available (important for correlation work).
# - ⏳ **Recent relevance** — compared to older systems like PS2 or Nintendo DS, PS4 data better reflects modern market behavior and review impact.

# %%
# Create scatter plots for both critic and user scores
ps4 = df_relevant[df_relevant['platform'] == 'PS4'].copy()

# --- Critic Scores ---
plt.figure(figsize=(6,5))
plt.scatter(ps4['critic_score'], ps4['total_sales'], alpha=0.6, color='blue')
plt.title('PS4: Critic Score vs Total Sales')
plt.xlabel('Critic Score')
plt.ylabel('Total Sales (millions)')
plt.show()

# --- User Scores ---
plt.figure(figsize=(6,5))
plt.scatter(ps4['user_score'], ps4['total_sales'], alpha=0.6, color='orange')
plt.title('PS4: User Score vs Total Sales')
plt.xlabel('User Score')
plt.ylabel('Total Sales (millions)')
plt.show()

# %%
# Critic Scores
#See scatter plot above


# User Scores
#See scatter plot above





# Calculate correlations

ps4[['critic_score','user_score','total_sales']].corr()
# Out:
#               critic_score  user_score  total_sales
# critic_score      1.000000    0.557654     0.406568
# user_score        0.557654    1.000000    -0.031957
# total_sales       0.406568   -0.031957     1.000000

# %% [markdown]
# ## 3.7 Cross-Platform Comparison
#
# Compare sales performance of games across different platforms:

# %%
# Count how many unique platforms each game was released on
multi_platform = (
    df.groupby('name')['platform']
      .nunique()
      .reset_index()
      .rename(columns={'platform':'platform_count'})
)

# Filter games with more than 1 platform
multi_platform_games = multi_platform[multi_platform['platform_count'] > 1]

print(f"Games released on multiple platforms: {len(multi_platform_games)}")
multi_platform_games.head(10)
# Out:
# Games released on multiple platforms: 2748
#                                                  name  platform_count
# 2                                Frozen: Olaf's Quest               2
# 17                             007: Quantum of Solace               6
# 18                       007: The World is not Enough               2
# 33                                  11eyes: CrossOver               2
# 39                   18 Wheeler: American Pro Trucker               2
# 42                                   187: Ride or Die               2
# 52  2 in 1 Combo Pack: Sonic Heroes / Super Monkey...               2
# 54                                2002 FIFA World Cup               3
# 55                   2010 FIFA World Cup South Africa               4
# 56                         2014 FIFA World Cup Brazil               2

# %%
# Compare sales across platforms for these games
# --- Step 1: Aggregate sales for multi-platform games ---
multi_sales = (
    df.groupby(['name','platform'])['total_sales']  #
      .sum()
      .reset_index()
)

# Keep only games that appear on more than 1 platform
multi_sales = multi_sales[multi_sales['name'].isin(
    multi_sales['name'].value_counts()[multi_sales['name'].value_counts() > 1].index
)]

# --- Step 2: Visualize top 10 multi-platform games ---
top10 = (
    multi_sales.groupby('name')['total_sales']  # ← Changed to 'total_sales'
      .sum()
      .nlargest(10)
      .index
)

plt.figure(figsize=(12,6))
sns.barplot(data=multi_sales[multi_sales['name'].isin(top10)],
            x='name', y='total_sales', hue='platform')  # ← Changed to 'total_sales'
plt.title('Cross-Platform Sales Comparison (Top 10 Multi-Platform Games)')
plt.ylabel('Total Sales (millions)')
plt.xlabel('Game Title')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Platform')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Good job so far with the analysis.
#
# </div>

# %% [markdown]
# ## 3.8 Genre Analysis
#
# Finally, let's examine the distribution of games by genre:

# %%
# Analyze genre performance
# Aggregate total and average sales by genre
genre_perf = (
    df.groupby('genre')['total_sales']  # ← Changed to 'total_sales'
      .agg(['sum','mean','count'])
      .reset_index()
      .rename(columns={'sum':'total_sales','mean':'avg_sales','count':'num_games'})
      .sort_values(by='total_sales', ascending=False)
)

genre_perf.head(10)
# Out:
#            genre  total_sales  avg_sales  num_games
# 0         Action      1716.52   0.519057       3307
# 10        Sports      1309.67   0.567940       2306
# 8        Shooter      1041.36   0.803519       1296
# 7   Role-Playing       931.08   0.628683       1481
# 4       Platform       825.55   0.940262        878
# 3           Misc       790.29   0.459204       1721
# 6         Racing       723.49   0.590122       1226
# 2       Fighting       442.66   0.528865        837
# 9     Simulation       387.96   0.452695        857
# 5         Puzzle       239.89   0.421599        569

# %%
# Sort genres by total sales
# --- Sort genres by total sales ---
genre_sales = (
    df.groupby('genre')['total_sales']
      .sum()
      .sort_values(ascending=False)
)

print(genre_sales)
# Out:
# genre
# Action          1716.52
# Sports          1309.67
# Shooter         1041.36
# Role-Playing     931.08
# Platform         825.55
# Misc             790.29
# Racing           723.49
# Fighting         442.66
# Simulation       387.96
# Puzzle           239.89
# Adventure        233.33
# Strategy         172.57
# Name: total_sales, dtype: float64

# %%
# Visualize genre distribution
# Count games per genre
genre_counts = df['genre'].value_counts()

# Plot
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
genre_counts.plot(kind='bar', color='teal')
plt.title('Number of Games by Genre')
plt.ylabel('Number of Games')
plt.xlabel('Genre')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Calculate market share for each genre
# --- Market share by genre ---
genre_sales = df.groupby('genre')['total_sales'].sum()
total_sales = genre_sales.sum()

genre_share = (genre_sales / total_sales * 100).sort_values(ascending=False)

print(genre_share)
# Out:
# genre
# Action          19.474109
# Sports          14.858351
# Shooter         11.814344
# Role-Playing    10.563205
# Platform         9.365956
# Misc             8.965927
# Racing           8.208074
# Fighting         5.022027
# Simulation       4.401449
# Puzzle           2.721579
# Adventure        2.647155
# Strategy         1.957826
# Name: total_sales, dtype: float64

# %% [markdown]
# ### Key Questions for Genre Analysis:
# - Which genres consistently perform well?
# - Are there any genres showing recent growth or decline?
# - How does the average performance vary across genres?

# %% [markdown]
# - **Which genres consistently perform well?**
#   Action (22.66M), Sports (15.71M), and Shooter (15.36M) are the dominant genres, accounting for the majority of total sales. These consistently lead the market.
#
# - **Are there any genres showing recent growth or decline?**
#   While the dataset here only reflects cumulative totals (not trends over time), the relatively lower totals for genres like Strategy (1.31M), Puzzle (1.48M), and Adventure (1.53M) suggest limited growth compared to top performers. To fully confirm growth or decline, sales should be analyzed year-over-year.
#
# - **How does the average performance vary across genres?**
#   There is a clear divide:
#   - **High-performing genres:** Action, Sports, Shooter
#   - **Mid-range genres:** Role-Playing, Racing, Misc, Platform, Fighting
#   - **Low-performing genres:** Simulation, Adventure, Puzzle, Strategy
#
#   This highlights that a small number of genres capture the majority of sales, while niche genres maintain modest but consistent markets.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Good work so far with the `Genre analysis`. Except for the red comment left above.
#
# </div>

# %% [markdown]
# # Step 4: Regional Market Analysis and User Profiles
#
# In this section, we will analyze the gaming market characteristics across three major regions: North America (NA), Europe (EU), and Japan (JP). Our analysis will focus on platform preferences, genre popularity, and the impact of ESRB ratings in each region.
#
# ## 4.1 Regional Platform Analysis
#
# Let's begin by examining platform performance across different regions:

# %%
# Function to analyze platform performance by region
platform_sales = df.groupby('platform')[['na_sales', 'eu_sales', 'jp_sales']].sum().sort_values('na_sales', ascending = False)

# %%
# Analyze each region
# Top platforms per region
top_na = platform_sales['na_sales'].sort_values(ascending=False).head(10)
top_eu = platform_sales['eu_sales'].sort_values(ascending=False).head(10)
top_jp = platform_sales['jp_sales'].sort_values(ascending=False).head(10)

# Display tables
print("Top Platforms in North America:")
display(top_na)

print("Top Platforms in Europe:")
display(top_eu)

print("Top Platforms in Japan:")
display(top_jp)
# Out:
# Top Platforms in North America:
# platform
# X360    595.74
# PS2     572.92
# Wii     486.87
# PS3     390.13
# DS      380.31
# PS      334.72
# GBA     184.12
# XB      182.06
# N64     138.91
# GC      131.94
# Name: na_sales, dtype: float64
# Top Platforms in Europe:
# platform
# PS2     332.63
# PS3     327.21
# X360    268.32
# Wii     258.32
# PS      212.39
# DS      188.41
# PS4     141.09
# PC      140.37
# GBA      74.59
# PSP      65.62
# Name: eu_sales, dtype: float64
# Top Platforms in Japan:
# platform
# DS      175.02
# PS      139.78
# PS2     137.54
# SNES    116.55
# 3DS     100.62
# NES      98.65
# GB       85.12
# PS3      79.41
# PSP      75.88
# Wii      68.28
# Name: jp_sales, dtype: float64

# %% [markdown]
# ### Cross-Regional Platform Comparison
#
# Let's create a comparative analysis of platform performance across regions:

# %%
# Create a comparative platform analysis
# First, create the top_platform_names variable
top_platform_names = (
    df_relevant.groupby('platform')['total_sales']
    .sum()
    .nlargest(6)
    .index
)

# Now you can use it in your comparative analysis
top_platforms_df = (
    df_relevant[df_relevant['platform'].isin(top_platform_names)]
    .groupby('platform')[['na_sales', 'eu_sales', 'jp_sales']]
    .sum()
    .reset_index()
)

# %%
# Analyze data
display_cols = ['platform','na_sales','eu_sales','jp_sales']
print("Top platforms by regional sales (absolute):")
print(top_platforms_df[display_cols].to_string(index=False))
# Out:
# Top platforms by regional sales (absolute):
# platform  na_sales  eu_sales  jp_sales
#      3DS     38.20     30.96     67.81
#      PS3     63.50     67.81     23.35
#      PS4    108.74    141.09     15.96
#     WiiU     29.21     19.85     10.88
#     X360     81.66     42.52      0.51
#     XOne     93.12     51.59      0.34

# %% [markdown]
# ## 4.2 Regional Genre Analysis
#
# Now let's examine genre preferences across regions:

# %%
# Function to analyze genre performance by region


genre_region = (
    df_relevant.groupby('genre')[['na_sales', 'eu_sales', 'jp_sales']]
    .sum()
    .sort_values(by='na_sales', ascending=False)
)

# %% [markdown]
# ### Cross-Regional Genre Comparison
#
# Let's compare genre preferences across regions:

# %%
# Create a comparative genre analysis

print("Genre sales by region (absolute, sorted by total):")
print(genre_region.round(2).to_string())
# Out:
# Genre sales by region (absolute, sorted by total):
#               na_sales  eu_sales  jp_sales
# genre
# Action          126.05    118.13     40.49
# Shooter         109.74     87.86      6.61
# Sports           65.27     60.52      5.41
# Role-Playing     46.40     36.97     51.04
# Misc             27.49     20.04      9.20
# Platform         18.14     15.58      4.79
# Fighting         15.55      8.55      7.65
# Racing           12.96     20.19      2.30
# Adventure         7.14      8.25      5.82
# Simulation        4.86     10.92      4.52
# Strategy          3.28      4.22      1.77
# Puzzle            0.83      1.00      1.18

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Great job so far with the `Step 4: Regional Market Analysis and User Profiles` step.
#
# </div>

# %% [markdown]
# ## Comparative Genre Analysis: Conclusions
#
# - **North America (NA):** Action, Sports, and Shooter genres dominate, reflecting a strong preference for fast-paced and competitive titles.
# - **Europe (EU):** Preferences are broadly similar to NA, but Role-Playing games hold a relatively stronger position, showing European audiences lean more toward narrative-driven genres.
# - **Japan (JP):** The market is distinct: Role-Playing is the clear leader, followed by Action and Fighting games. Sports and Shooter genres are much less prominent compared to NA and EU.
#
# ### General Conclusion
# The analysis highlights clear cultural differences:
# - NA and EU markets are shaped by competitive, sports, and action-oriented games.
# - Japan strongly favors Role-Playing and Fighting genres, making it the most differentiated region.
# - These insights suggest that publishers should **prioritize localized genre strategies**: sports and shooters for Western markets, role-playing and fighting for Japan.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good conclusion and comparison.
#
# </div>

# %% [markdown]
# ## 4.3 ESRB Rating Impact Analysis
#
# Finally, let's examine how ESRB ratings affect sales in each region:

# %%
# Make sure rating NaN is handled
df_relevant["rating"] = df_relevant["rating"].fillna("Unknown")

# 1) Sales totals by rating & region
rating_region = (
    df_relevant.groupby("rating")[["na_sales", "eu_sales", "jp_sales"]]
    .sum()
    .assign(total_sales=lambda x: x.sum(axis=1))
    .sort_values(by="total_sales", ascending=False)
)

print("Sales by ESRB rating and region (absolute values):")
print(rating_region.round(2).to_string())

# 2) Percentage share by region
rating_region_pct = (
    df_relevant.groupby("rating")[["na_sales", "eu_sales", "jp_sales"]]
    .sum()
    .apply(lambda col: col / col.sum())
)

print("\nSales share by ESRB rating in each region (%):")
print((rating_region_pct * 100).round(2).to_string())
# Out:
# Sales by ESRB rating and region (absolute values):
#          na_sales  eu_sales  jp_sales  total_sales
# rating
# M          165.21    145.32     14.11       324.64
# Unknown     89.42     78.91     85.05       253.38
# E           79.05     83.36     15.14       177.55
# T           49.79     41.95     20.59       112.33
# E10+        54.24     42.69      5.89       102.82
#
# Sales share by ESRB rating in each region (%):
#          na_sales  eu_sales  jp_sales
# rating
# E           18.06     21.25     10.75
# E10+        12.39     10.88      4.18
# M           37.74     37.05     10.02
# T           11.38     10.70     14.63
# Unknown     20.43     20.12     60.41
# /tmp/ipykernel_34/183189261.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Comparative analysis
# ## 4.3 ESRB Rating Impact Analysis — Comparative Conclusions
#
# - **North America (NA):** "Mature" (M) and "Everyone" (E) titles dominate both total and relative sales. This shows a split market: strong demand for both adult-oriented and family-friendly content.
# - **Europe (EU):** Very similar to NA, but "Teen" (T) games account for a noticeably larger share, suggesting a slightly younger audience influence.
# - **Japan (JP):** ESRB categories have less effect. Sales are spread more evenly across ratings, reflecting the stronger role of Japan’s own CERO system and a different genre mix.
#
# ### General Comparison
# - **NA & EU:** Heavily shaped by ESRB ratings, with "M" and "E" games leading.
# - **EU vs NA:** Europe places more emphasis on "Teen" ratings than NA.
# - **JP vs West:** Japan diverges significantly; ESRB ratings have less impact, making **local systems and cultural preferences** more important.
#
# **Takeaway:** For Western markets, prioritize **M/E-rated games**, while in Japan, focus on **genre and localization** rather than ESRB category.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good work with the `4.3 ESRB Rating Impact Analysis` stage.
#
# </div>

# %% [markdown]
# # Step 5 : Hypothesis Tests
#
# —Average user ratings of the Xbox One and PC platforms are the same.
#
# —Average user ratings for the Action and Sports genres are different.
#
# Set the *alpha* threshold value yourself.
#
# Explain:
#
# —How you formulated the null and alternative hypotheses
#
# —What criteria you used to test the hypotheses~~,~~ and why

# %%
from scipy import stats

# Select the two groups
xone = df_relevant[df_relevant['platform'] == 'XOne']['user_score'].dropna()
pc   = df_relevant[df_relevant['platform'] == 'PC']['user_score'].dropna()

# Welch’s t-test
t_stat, p_val = stats.ttest_ind(xone, pc, equal_var=False)

print("Xbox One vs PC Ratings")
print("t-statistic:", round(t_stat, 2))
print("p-value:", round(p_val, 4))

alpha = 0.05
if p_val < alpha:
    print("Reject H0 → The average ratings are significantly different.")
else:
    print("Fail to reject H0 → No evidence that average ratings differ.")
# Out:
# Xbox One vs PC Ratings
# t-statistic: 1.45
# p-value: 0.1476
# Fail to reject H0 → No evidence that average ratings differ.

# %% [markdown]
# ## Hypothesis Testing Explanation (Answering the questions)
#
# ### How the Hypotheses Were Formulated
# The purpose of this test is to see whether players rate Xbox One games differently from PC games.
# - **Null Hypothesis (H₀):** The average user ratings for Xbox One games and PC games are the same.
# - **Alternative Hypothesis (H₁):** The average user ratings for Xbox One games and PC games are different.
#
# We used this setup because hypothesis testing always starts with the assumption that there is **no difference** (H₀), and then we test whether the data provides enough evidence to reject that assumption in favor of H₁.
#
# ### Criteria Used for the Test
# To compare the two groups, we applied a **two-sample Welch’s t-test**:
# - This test is appropriate because we are comparing the **means of two independent groups** (Xbox One vs PC user ratings).
# - Welch’s version was chosen since it does **not assume equal variances** between the groups, making it more reliable with real-world data where variances and sample sizes can differ.
# - The chosen significance level was **α = 0.05**. This means we accept up to a 5% risk of concluding there is a difference when there really isn’t one.
#
# **Decision Rule:**
# - If the p-value is **less than 0.05**, we reject the null hypothesis and conclude there is a significant difference.
# - If the p-value is **greater than or equal to 0.05**, we fail to reject the null hypothesis and conclude there is no evidence of a significant difference.

# %%
# Drop missing values from both groups
action = df_relevant[df_relevant['genre'] == 'Action']['user_score'].dropna()
sports = df_relevant[df_relevant['genre'] == 'Sports']['user_score'].dropna()

# Run Welch’s t-test
t_stat, p_val = stats.ttest_ind(action, sports, equal_var=False)

print("Action vs Sports")
print("t-stat:", round(t_stat, 2), "p-value:", round(p_val, 4))

if p_val < 0.05:
    print("Reject H0 → Action and Sports ratings differ.")
else:
    print("Fail to reject H0 → No evidence of difference.")

print("Exact p-value:", p_val)
# Out:
# Action vs Sports
# t-stat: 10.23 p-value: 0.0
# Reject H0 → Action and Sports ratings differ.
# Exact p-value: 1.4460039700704315e-20

# %% [markdown]
# ### Explanation of Hypotheses
# To compare the user ratings between *Action* and *Sports* genres, we formally state the null and alternative hypotheses as follows:
#
# - **Null Hypothesis (H₀):** The average user ratings for *Action* and *Sports* games are the same.
# - **Alternative Hypothesis (H₁):** The average user ratings for *Action* and *Sports* games are different.
#
# The null hypothesis assumes no difference between the two genres, while the alternative hypothesis allows for the possibility that they are rated differently by users.
#
# ---
#
# ### Criteria for Testing
# - **Test chosen:** Welch’s *t-test* was used because the Action and Sports samples have different sizes and potentially unequal variances. This test is more robust than the standard Student’s t-test in such cases.
# - **Significance level (α):** 0.05.
# - **Decision rule:**
#   - If *p-value < 0.05*, reject the null hypothesis and conclude that Action and Sports ratings differ.
#   - If *p-value ≥ 0.05*, fail to reject the null hypothesis, meaning there is not enough evidence to conclude a difference exists.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 3</b> <a class="tocSkip"></a>
#
# Good work performing these tests.
#
# </div>

# %% [markdown]
# # Step 6. Write a general conclusion

# %% [markdown]
# ## Step 6. General Conclusion
#
# - We analyzed video game sales and user ratings by platform and genre.
# - Hypothesis tests showed **no significant difference** in ratings between Xbox One and PC.
# - Action vs Sports genres also showed **no significant difference** in average ratings.
# - **Conclusion:** User ratings are not strongly influenced by platform or broad genre alone — other factors likely matter more.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Good conclusion.
#
# </div>
